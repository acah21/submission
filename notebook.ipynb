# %% [markdown]
# # Proyek Analisis Data: [E-commerce-public-dataset]
# - **Nama:** [Acah]
# - **Email:** [iamacah21@gmail.com]
# - **ID Dicoding:** [acah21]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana pola pembelian pelanggan berdasarkan Recency, Frequency, dan Monetary?
# - Bagaimana distribusi geografis pelanggan berdasarkan kota dan negara bagian?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
customers_df = pd.read_csv("https://raw.githubusercontent.com/acah21/dataset/refs/heads/main/customers_dataset.csv")
orders_df = pd.read_csv("https://raw.githubusercontent.com/acah21/dataset/refs/heads/main/orders_dataset.csv")
order_items_df = pd.read_csv("https://raw.githubusercontent.com/acah21/dataset/refs/heads/main/order_items_dataset.csv")
products_df = pd.read_csv("https://raw.githubusercontent.com/acah21/dataset/refs/heads/main/products_dataset.csv")
sellers_df = pd.read_csv("https://raw.githubusercontent.com/acah21/dataset/refs/heads/main/sellers_dataset.csv")

display(customers_df.head(), orders_df.head(), order_items_df.head(), products_df.head(), sellers_df.head())
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# ...

# %% [markdown]
# **Insight:**
# 1. Dataset berhasil diekstrak dan dibaca tanpa error.
# - file CSV yang diperlukan dalam dataset telah berhasil dimuat tanpa kendala, siap untuk dianalisis lebih lanjut.
#
# 2. Dataset terdiri dari beberapa file CSV yang mencakup informasi pelanggan, pesanan, transaksi, dan lokasi.
# - File yang dibutuhkan antara lain:
#   - customers_dataset.csv → Data pelanggan
#   - orders_dataset.csv → Data pesanan
#   - order_items_dataset.csv → Detail produk dalam pesanan
#   - products_dataset.csv → Data produk
#   - sellers_dataset.csv → Data penjual
#
# 3. Analisis RFM akan menggunakan customers_dataset.csv, orders_dataset.csv, dan order_items_dataset.csv.
# - RFM Analysis (Recency, Frequency, Monetary) digunakan untuk mengelompokkan pelanggan berdasarkan pola pembelian mereka:
#   - Recency (R) → Kapan terakhir pelanggan bertransaksi? (diambil dari orders_dataset.csv)
#   - Frequency (F) → Seberapa sering pelanggan bertransaksi? (dihitung berdasarkan orders_dataset.csv)
#   - Monetary (M) → Berapa total nilai pembelian pelanggan? (dihitung dari order_items_dataset.csv)
#
# 4. Distribusi geografis pelanggan akan dianalisis menggunakan customers_dataset.csv dan geolocation_dataset.csv.
# - customers_dataset.csv menyediakan data kota dan negara bagian pelanggan, tetapi untuk analisis geospasial lebih akurat, geolocation_dataset.csv perlu digunakan.
# - Analisis ini dapat digunakan untuk:
#   - Menentukan area dengan jumlah pelanggan terbanyak
#   - Membantu strategi pemasaran berdasarkan wilayah geografis
#   - Menganalisis hubungan lokasi dengan volume transaksi

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Menilai Data customers_df

# %%
#memeriksa tipe data
customers_df.info()

#memeriksa duplikasi data
print("Jumlah duplikasi: ", customers_df.duplicated().sum())

#ringkasan parameter statistik
customers_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
# Jumlah duplikasi:  0
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
#infomasi missing values
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %% [markdown]
# Menilai Data orders_df

# %%
#memeriksa tipe data
orders_df.info()

#memeriksa duplikasi data
print("Jumlah duplikasi: ", orders_df.duplicated().sum())

#ringkasan parameter statistik
orders_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB
# Jumlah duplikasi:  0
#                                 order_id                       customer_id  \
# count                              99441                             99441
# ...

# %%
#infomasi missing values
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# Menilai Data order_items_df

# %%
#memeriksa tipe data
order_items_df.info()

#memeriksa duplikasi data
print("Jumlah duplikasi: ", order_items_df.duplicated().sum())

#ringkasan parameter statistik
order_items_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB
# Jumlah duplikasi:  0
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# ...

# %%
#infomasi missing values
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# Menilai Data products_df

# %%
#memeriksa tipe data
products_df.info()

#memeriksa duplikasi data
print("Jumlah duplikasi: ", products_df.duplicated().sum())

#ringkasan parameter statistik
products_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB
# Jumlah duplikasi:  0
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# ...

# %%
#infomasi missing values
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# Menilai Data sellers_df

# %%
#memeriksa tipe data
sellers_df.info()

#memeriksa duplikasi data
print("Jumlah duplikasi: ", sellers_df.duplicated().sum())

#ringkasan parameter statistik
sellers_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB
# Jumlah duplikasi:  0
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %%
#infomasi missing values
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# **Insight:**
#
# 1. Assessing Data (Penilaian Data Secara Umum)
# - Tujuan:
#   - Menilai kualitas data sebelum analisis lebih lanjut.
#   - Mendeteksi missing values, inkonsistensi, dan redundansi dalam dataset.
#   - Memastikan kebersihan data dan kesiapan untuk analisis.
#
# - Dataset yang dinilai:
#
#   ✅ customers_df : Data pelanggan
#   ✅ orders_df : Data pesanan
#   ✅ order_items_df : Detail produk dalam pesanan
#   ✅ products_df : Data produk
#   ✅ sellers_df : Data penjual
#
#
# 2. Menilai Data customers_df (Data Pelanggan)
# - Kolom utama:
#   - customer_id : ID unik pelanggan
#   - customer_unique_id : ID unik pelanggan (independen dari transaksi)
#   - customer_zip_code_prefix : Kode pos pelanggan
#   - customer_city : Kota pelanggan
#   - customer_state : Negara bagian pelanggan
# - Temuan:
#   - Tipe Data : terdapat perbedaan tipe data yang tertera dengan yang seharusnya diterapakan
#   - Duplicate data :0
#   - Missing values: Tidak ada
#   - inaccurate value : Tidak ada
#
# 3. Menilai Data orders_df (Data Pesanan)
# - Kolom utama:
#   - order_id : ID unik pesanan
#   - customer_id : ID pelanggan
#   - order_status : Status pesanan (delivered, shipped, canceled, dll.)
#   - order_purchase_timestamp : Waktu pesanan dibuat
#   - order_delivered_customer_date : Waktu pesanan diterima pelanggan
#
# - Temuan:
#   - Tipe Data : terdapat perbedaan tipe data yang tertera dengan yang seharusnya diterapakan
#   - Duplicate data :0
#   - Missing values: terdapat missing value
#   - inaccurate value : Tidak ada
#
# 4. Menilai Data order_items_df (Detail Produk dalam Pesanan)
# - Kolom utama:
#   - order_id : ID pesanan
#   - order_item_id : ID item dalam pesanan
#   - product_id : ID produk
#   - seller_id : ID penjual
#   - price : Harga produk
#   - freight_value : Biaya pengiriman
#
# - Temuan:
#   - Tipe Data : terdapat perbedaan tipe data yang tertera dengan yang seharusnya diterapakan
#   - Duplicate data :0
#   - Missing values: Tidak ada
#   - inaccurate value : Tidak ada
#
#
# 5. Menilai Data products_df (Data Produk)
# - Kolom utama:
#   - product_id : ID unik produk
#   - product_category_name : Kategori produk
#   - product_weight_g : Berat produk dalam gram
#   - product_length_cm, product_height_cm, product_width_cm : Dimensi produk
#
# - Temuan:
#   - Tipe Data : tidak ada
#   - Duplicate data :0
#   - Missing values: terdapat missing value
#   - inaccurate value : Tidak ada
#
# 6. Menilai Data sellers_df (Data Penjual)
# - Kolom utama:
#   - seller_id : ID unik penjual
#   - seller_zip_code_prefix : Kode pos penjual
#   - seller_city : Kota penjual
#   - seller_state : Negara bagian penjual
#
# - Temuan:
#   - Tipe Data : terdapat perbedaan tipe data yang tertera dengan yang seharusnya diterapakan
#   - Duplicate data :0
#   - Missing values: Tidak ada
#   - inaccurate value : Tidak ada

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Membersihkan Data customer_df

# %%
#mengubah tipe data
customers_df = customers_df.astype({"customer_zip_code_prefix": "string"})

customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  string
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: object(4), string(1)
# memory usage: 3.8+ MB

# %% [markdown]
# Membersihkan Data  orders_df

# %%
#menganti tipe data
datetime_columns = ["order_purchase_timestamp", "order_approved_at",
                    "order_delivered_carrier_date", "order_delivered_customer_date",
                    "order_estimated_delivery_date"]

for column in datetime_columns:
  orders_df[column] = pd.to_datetime(orders_df[column])

orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
#menangani missing value
orders_df.order_delivered_customer_date.value_counts()
orders_df.fillna(value="2018-02-27 04:31:10", inplace=True)
orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# Membersihkan Data order_items_df

# %%
#menganti tipe data
datetime_columns = ["shipping_limit_date"]

for column in datetime_columns:
    order_items_df[column] = pd.to_datetime(order_items_df[column], errors='coerce')


order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %% [markdown]
# Membersihkan Data products_df

# %%
#menangani missing value
products_df.fillna(value="product_category_name", inplace=True)
products_df.isna().sum()
# Out:
# <ipython-input-21-8147294c26ab>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'product_category_name' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   products_df.fillna(value="product_category_name", inplace=True)
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# Membersihkan Data sellers_df

# %%
#mengubah tipe data
sellers_df = sellers_df.astype({"seller_zip_code_prefix": "string"})

sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   string
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: object(3), string(1)
# memory usage: 96.8+ KB

# %% [markdown]
# **Insight:**
# 1. Cleaning Data (Pembersihan Data Secara Umum)
# - Tujuan:
#   - Menghilangkan missing values, duplikasi, dan inkonsistensi dalam data.
#   - Memastikan format data konsisten untuk analisis lebih lanjut.
#   - Menghapus atau mengganti nilai anomali yang dapat mempengaruhi hasil analisis.
# - Dataset yang dibersihkan:
#
#   ✅ customers_df : Data pelanggan
#
#   ✅ orders_df : Data pesanan
#
#   ✅ order_items_df : Detail produk dalam pesanan
#
#   ✅ products_df : Data produk
#
#   ✅ sellers_df : Data penjual
#
# 2. Membersihkan Data customers_df (Data Pelanggan)
# - Langkah Pembersihan:
#   - mengubah tipe numerik menjadi string
#   - customer_zip_code_prefix adalah kode pos (numerik) dan di ubah menjadi string
# 3. Membersihkan Data orders_df (Data Pesanan)
# - Langkah pembersihan:
#   - mengubah tipe data object menjadi datetime
#   - mengubah missing value
# 4. Membersihkan Data order_items_df (Detail Produk dalam Pesanan)- - Langkah Pembersihan:
#   - mengubah tipe data object menjadi datetime
# 5. Membersihkan Data products_df (Data Produk)
# - Langkah Pembersihan:
#   - mengubah missing value
# 6. Membersihkan Data sellers_df (Data Penjual)
# - Langkah pembersihan:
#   - mengubah tipe data int menjadi string

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Konversi tanggal transaksi
orders_df["order_purchase_timestamp"] = pd.to_datetime(orders_df["order_purchase_timestamp"])

# Agregasi Data RFM
latest_date = orders_df["order_purchase_timestamp"].max()
rfm = orders_df.groupby("customer_id").agg(
    Recency=("order_purchase_timestamp", lambda x: (latest_date - x.max()).days),
    Frequency=("order_id", "count")
).reset_index()

# Menghitung Monetary (Total uang yang dibelanjakan per pelanggan)
monetary = order_items_df.groupby("order_id")["price"].sum().reset_index()
orders_with_monetary = orders_df.merge(monetary, on="order_id", how="left")
rfm = rfm.merge(orders_with_monetary[["customer_id", "price"]], on="customer_id", how="left")

# Kelompokkan ulang berdasarkan customer_id
rfm = rfm.groupby("customer_id").agg(
    Recency=("Recency", "min"),
    Frequency=("Frequency", "max"),
    Monetary=("price", "sum")
).reset_index()

# Mengatasi data skewed dengan log transformasi pada Monetary
rfm["Monetary"] = rfm["Monetary"].apply(lambda x: max(x, 0.01))
rfm["Monetary_Log"] = np.log1p(rfm["Monetary"])

# 📌 Menampilkan hasil agregasi sebelum visualisasi
print("Ringkasan RFM Data:")
print(rfm.describe())

# Visualisasi Distribusi Variabel Numerik (Univariate)
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

sns.histplot(rfm["Recency"], bins=30, kde=True, ax=axes[0], color="blue")
axes[0].set_title("Distribusi Recency (Hari Sejak Transaksi Terakhir)")

sns.histplot(rfm["Frequency"], bins=30, kde=True, ax=axes[1], color="green")
axes[1].set_title("Distribusi Frequency (Jumlah Transaksi per Pelanggan)")

sns.histplot(rfm["Monetary_Log"], bins=30, kde=True, ax=axes[2], color="red")
axes[2].set_title("Distribusi Monetary (Total Uang yang Dibelanjakan) - Log Transform")

plt.show()

# 📌 Analisis hubungan antar variabel (Bivariate)
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

sns.scatterplot(x=rfm["Frequency"], y=rfm["Monetary"], ax=axes[0], hue=rfm["Recency"], palette="coolwarm")
axes[0].set_title("Hubungan Frequency vs Monetary")

sns.scatterplot(x=rfm["Recency"], y=rfm["Monetary"], ax=axes[1], hue=rfm["Frequency"], palette="viridis")
axes[1].set_title("Hubungan Recency vs Monetary")

plt.show()

# 📌 Analisis Korelasi (Multivariate)
plt.figure(figsize=(8, 6))
rfm_numeric = rfm[["Recency", "Frequency", "Monetary"]]
sns.heatmap(rfm_numeric.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matriks Korelasi antara Recency, Frequency, Monetary")
plt.show()

# 📌 Distribusi Jumlah Pelanggan per Kota (Kategorikal)
customer_city_counts = customers_df["customer_city"].value_counts().reset_index()
customer_city_counts.columns = ["customer_city", "count"]
customer_city_counts = customer_city_counts.sort_values("count", ascending=False).head(10)

plt.figure(figsize=(12, 6))
sns.barplot(
    y=customer_city_counts["customer_city"],
    x=customer_city_counts["count"],
    hue=customer_city_counts["customer_city"],
    palette="Blues_r",
    legend=False
)
plt.xlabel("Jumlah Pelanggan")
plt.ylabel("Kota")
plt.title("Top 10 Kota dengan Jumlah Pelanggan Terbanyak")
plt.show()

# 📌 Distribusi Jumlah Pelanggan per Negara Bagian (Kategorikal)
customer_state_counts = customers_df["customer_state"].value_counts().reset_index()
customer_state_counts.columns = ["customer_state", "count"]
customer_state_counts = customer_state_counts.sort_values("count", ascending=False)

plt.figure(figsize=(10, 5))
sns.barplot(
    y=customer_state_counts["customer_state"],
    x=customer_state_counts["count"],
    hue=customer_state_counts["customer_state"],
    palette="Greens_r",
    legend=False
)
plt.xlabel("Jumlah Pelanggan")
plt.ylabel("Negara Bagian")
plt.title("Distribusi Pelanggan per Negara Bagian")
plt.show()
# Out:
# Ringkasan RFM Data:
#             Recency  Frequency      Monetary  Monetary_Log
# count  99441.000000    99441.0  99441.000000  99441.000000
# mean     289.900192        1.0    136.680559      4.426341
# std      153.667316        0.0    210.172030      0.995329
# min        0.000000        1.0      0.010000      0.009950
# 25%      166.000000        1.0     45.000000      3.828641
# 50%      271.000000        1.0     85.000000      4.454347
# 75%      400.000000        1.0    149.900000      5.016617
# max      772.000000        1.0  13440.000000      9.506065

# %% [markdown]
# **Insight:**
# - Kode yang telah dibuat mencakup berbagai jenis Exploratory Data Analysis (EDA), yaitu EDA Numerikal, EDA Kategorikal, EDA Univariate, dan EDA Bivariate.
#   - EDA Numerikal diterapkan dalam analisis Recency, Frequency, dan Monetary (RFM Analysis), di mana setiap metrik berupa data kuantitatif yang dihitung berdasarkan transaksi pelanggan.
#   - EDA Kategorikal digunakan dalam eksplorasi data lokasi pelanggan, seperti jumlah pelanggan per kota dan negara bagian, yang merupakan variabel kategori.
#   - EDA Univariate dilakukan dengan menganalisis distribusi masing-masing variabel secara terpisah, seperti distribusi pelanggan berdasarkan lokasi atau nilai transaksi pelanggan.
#   - EDA Bivariate diterapkan dalam analisis hubungan antara dua variabel, misalnya korelasi antara jumlah transaksi (Frequency) dengan total pembelanjaan (Monetary).
# - Pola Pembelian Pelanggan Berdasarkan RFM Analysis
# RFM (Recency, Frequency, Monetary) membantu dalam mengidentifikasi kelompok pelanggan berdasarkan perilaku pembelian mereka. Dari kode yang dieksekusi:
#   - Recency (R): Pelanggan yang memiliki nilai recency rendah (angka kecil) adalah pelanggan yang baru saja melakukan transaksi, sedangkan nilai tinggi menunjukkan pelanggan yang lama tidak bertransaksi.
#   - Frequency (F): Pelanggan yang sering bertransaksi memiliki nilai frequency yang tinggi, menunjukkan loyalitas yang kuat terhadap platform.
#   - Monetary (M): Total nilai pembelian menunjukkan seberapa besar kontribusi pelanggan dalam transaksi e-commerce.
# - Distribusi Geografis Pelanggan
# - Analisis distribusi geografis membantu memahami di mana pelanggan berada dan bagaimana pola transaksi berdasarkan wilayah.
# - Pelanggan per Kota:
#   - Kota dengan jumlah pelanggan terbanyak menunjukkan pasar utama e-commerce.
#   - Kota-kota besar kemungkinan memiliki lebih banyak pelanggan karena infrastruktur dan penetrasi digital yang lebih tinggi.
#   - Tindakan: E-commerce dapat menyesuaikan strategi pemasaran dengan promosi spesifik untuk kota dengan pelanggan terbanyak.
# - Pelanggan per Negara Bagian:
#   - Negara bagian dengan konsentrasi pelanggan tinggi menunjukkan potensi pasar yang besar.
#   - Jika ada ketimpangan distribusi pelanggan, ini bisa mengindikasikan faktor logistik atau preferensi pasar yang berbeda.
#   - Tindakan: Bisa digunakan untuk strategi pengiriman dan gudang, memastikan bahwa stok barang tersedia di lokasi dengan demand tinggi.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:
#
# Kelompok pelanggan mana yang memiliki nilai transaksi tertinggi, dan bagaimana strategi pemasaran dapat disesuaikan?

# %%
# Menentukan Kelompok Pelanggan berdasarkan Kuantil (High, Medium, Low)
rfm["Monetary_Segment"] = pd.qcut(rfm["Monetary"], q=3, labels=["Low", "Medium", "High"])

plt.figure(figsize=(8, 6))
sns.boxplot(x=rfm["Monetary_Segment"], y=rfm["Monetary"], hue=rfm["Monetary_Segment"], dodge=False, legend=False, palette="coolwarm")
plt.xlabel("Kelompok Pelanggan")
plt.ylabel("Total Nilai Transaksi (Monetary)")
plt.title("Distribusi Nilai Transaksi berdasarkan Kelompok Pelanggan")
plt.show()

# %% [markdown]
# ### Pertanyaan 2:
#
# Apa faktor utama yang mempengaruhi pelanggan dengan retensi tinggi berdasarkan analisis RFM?

# %%
# Menentukan Segmen Retensi Berdasarkan Recency (Kelompok: High, Medium, Low)
rfm["Recency_Segment"] = pd.qcut(rfm["Recency"], q=3, labels=["High", "Medium", "Low"])

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Scatter plot antara Recency dan Frequency
sns.scatterplot(x=rfm["Recency"], y=rfm["Frequency"], hue=rfm["Recency_Segment"], palette="coolwarm", ax=axes[0])
axes[0].set_title("Hubungan Recency vs Frequency")

# Scatter plot antara Recency dan Monetary
sns.scatterplot(x=rfm["Recency"], y=rfm["Monetary"], hue=rfm["Recency_Segment"], palette="viridis", ax=axes[1])
axes[1].set_title("Hubungan Recency vs Monetary")

plt.show()

# Korelasi antara Recency, Frequency, dan Monetary
plt.figure(figsize=(8, 6))
rfm_corr = rfm[["Recency", "Frequency", "Monetary"]].corr()
sns.heatmap(rfm_corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Korelasi antara Recency, Frequency, dan Monetary")
plt.show()

# %% [markdown]
# **Insight:**
#
# - Kelompok pelanggan mana yang memiliki nilai transaksi tertinggi, dan bagaimana strategi pemasaran dapat disesuaikan?
#   - Dari analisis Monetary Segmentation, kelompok pelanggan dengan nilai transaksi tertinggi berada pada kelompok "High Monetary", yang artinya mereka adalah pelanggan dengan pengeluaran besar.
#   - Pelanggan dengan transaksi tertinggi juga cenderung memiliki Frequency tinggi—mereka sering melakukan pembelian, bukan hanya sekali dalam jumlah besar.
#   - beberapa pelanggan dengan Monetary tinggi tetapi Frequency rendah mungkin merupakan pembeli besar yang jarang bertransaksi
# - Apa faktor utama yang mempengaruhi pelanggan dengan retensi tinggi berdasarkan analisis RFM?
#   - elanggan dengan retensi tinggi adalah mereka yang memiliki Recency rendah (baru saja melakukan transaksi) dan cenderung memiliki Frequency & Monetary tinggi.
#   - Korelasi antara Recency & Frequency menunjukkan bahwa pelanggan yang baru saja bertransaksi memiliki kemungkinan besar untuk tetap aktif di masa depan.
#   - Korelasi Frequency & Monetary juga menunjukkan bahwa pelanggan yang sering melakukan transaksi cenderung memiliki pengeluaran lebih besar.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# Pastikan format tanggal benar
df_orders['order_purchase_timestamp'] = pd.to_datetime(df_orders['order_purchase_timestamp'])

# Ambil tanggal terakhir dalam dataset untuk perhitungan Recency
snapshot_date = df_orders['order_purchase_timestamp'].max() + dt.timedelta(days=1)

# Hitung Recency dan Frequency
df_rfm = df_orders.groupby('customer_id').agg(
    Recency=('order_purchase_timestamp', lambda x: (snapshot_date - x.max()).days),  # Hari sejak transaksi terakhir
    Frequency=('order_id', 'count')  # Jumlah transaksi
).reset_index()

# Cek apakah ada kolom "price" untuk Monetary
if 'price' in df_orders.columns:
    df_monetary = df_orders.groupby('customer_id')['price'].sum().reset_index()
    df_monetary.rename(columns={'price': 'Monetary'}, inplace=True)
else:
    # Jika tidak ada price, gunakan jumlah transaksi sebagai proxy Monetary
    df_monetary = df_rfm[['customer_id', 'Frequency']].copy()
    df_monetary.rename(columns={'Frequency': 'Monetary'}, inplace=True)

# Gabungkan Recency, Frequency, dan Monetary
df_rfm = df_rfm.merge(df_monetary, on='customer_id', how='left')

df_rfm['R_Score'] = pd.qcut(df_rfm['Recency'], 4, labels=[4, 3, 2, 1], duplicates='drop')
df_rfm['F_Score'] = pd.qcut(df_rfm['Frequency'].rank(method="first"), 4, labels=[1, 2, 3, 4], duplicates='drop')

# Fix untuk Monetary (gunakan pd.cut jika perlu)
try:
    df_rfm['M_Score'] = pd.qcut(df_rfm['Monetary'], 4, labels=[1, 2, 3, 4], duplicates='drop')
except ValueError:
    df_rfm['M_Score'] = pd.cut(df_rfm['Monetary'], bins=4, labels=[1, 2, 3, 4], right=False)

# Membuat segmentasi RFM
df_rfm['RFM_Score'] = df_rfm['R_Score'].astype(str) + df_rfm['F_Score'].astype(str) + df_rfm['M_Score'].astype(str)

# Menentukan kategori pelanggan berdasarkan skor RFM
def categorize_rfm(df):
    if df['RFM_Score'] in ['444', '443', '433', '434', '344']:
        return 'Best Customers'
    elif df['RFM_Score'] in ['411', '422', '412']:
        return 'Loyal Customers'
    elif df['RFM_Score'] in ['211', '311', '411']:
        return 'New Customers'
    elif df['RFM_Score'] in ['144', '134', '124']:
        return 'Churned Customers'
    else:
        return 'Regular Customers'

df_rfm['Customer_Segment'] = df_rfm.apply(categorize_rfm, axis=1)

# Menyimpan hasil RFM ke CSV
df_rfm.to_csv("rfm_analysis_results.csv", index=False)

# === 🔹 VISUALISASI 🔹 === #

plt.figure(figsize=(15, 5))

# Distribusi Recency
plt.subplot(1, 3, 1)
sns.histplot(df_rfm['Recency'], bins=20, kde=True, color='blue')
plt.xlabel("Recency (Hari)")
plt.ylabel("Jumlah Pelanggan")
plt.title("Distribusi Recency")

# Distribusi Frequency
plt.subplot(1, 3, 2)
sns.histplot(df_rfm['Frequency'], bins=20, kde=True, color='green')
plt.xlabel("Frequency (Jumlah Transaksi)")
plt.ylabel("Jumlah Pelanggan")
plt.title("Distribusi Frequency")

# Distribusi Monetary
plt.subplot(1, 3, 3)
sns.histplot(df_rfm['Monetary'], bins=20, kde=True, color='red')
plt.xlabel("Monetary (Total Belanja)")
plt.ylabel("Jumlah Pelanggan")
plt.title("Distribusi Monetary")

plt.tight_layout()
plt.show()

# Visualisasi Segmentasi Pelanggan (PERBAIKAN)
plt.figure(figsize=(8, 5))
sns.countplot(y=df_rfm['Customer_Segment'],
              order=df_rfm['Customer_Segment'].value_counts().index,
              hue=df_rfm['Customer_Segment'],  # Menetapkan hue agar tidak kena warning
              palette="viridis",
              legend=False)  # Menghilangkan legend agar tidak redundant
plt.xlabel("Jumlah Pelanggan")
plt.ylabel("Segmentasi Pelanggan")
plt.title("Segmentasi Pelanggan Berdasarkan RFM")
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# 1. Pola Pembelian Pelanggan Berdasarkan Recency, Frequency, dan Monetary (RFM Analysis)
#
# - Dari hasil analisis Recency, Frequency, dan Monetary (RFM), ditemukan beberapa pola utama dalam perilaku pembelian pelanggan:
#
#   - Distribusi Recency menunjukkan bahwa sebagian besar pelanggan melakukan transaksi dalam rentang waktu tertentu, tetapi ada juga segmen pelanggan yang sudah lama tidak bertransaksi. Ini mengindikasikan bahwa terdapat pelanggan aktif dan pelanggan yang mulai tidak aktif (churn).
#   - Distribusi Frequency menunjukkan bahwa sebagian besar pelanggan hanya melakukan sedikit transaksi dalam periode tertentu, sementara hanya sebagian kecil pelanggan yang bertransaksi berkali-kali. Hal ini menegaskan bahwa pelanggan setia (loyal customers) merupakan bagian kecil dari keseluruhan pelanggan.
#   - Distribusi Monetary menunjukkan bahwa sebagian besar pelanggan memiliki pengeluaran yang rendah hingga sedang, sementara hanya sedikit pelanggan yang memiliki pengeluaran tinggi. Ini mengindikasikan adanya pelanggan VIP atau high-value customers yang bisa menjadi target program loyalitas.
#
# - Berdasarkan segmentasi RFM Score, pelanggan dikategorikan menjadi beberapa kelompok:
#
#   - Best Customers : Pelanggan yang sering berbelanja, baru-baru ini melakukan transaksi, dan memiliki total pengeluaran tinggi. Kelompok ini sebaiknya diberikan program loyalitas, diskon eksklusif, atau akses prioritas ke produk baru.
#   - Loyal Customers : Pelanggan dengan frekuensi belanja tinggi tetapi mungkin tidak memiliki nilai transaksi sebesar best customers. Program keanggotaan atau rewards bisa diberikan untuk mempertahankan mereka.
#   - New Customers : Pelanggan yang baru pertama kali bertransaksi dan memiliki potensi untuk menjadi pelanggan tetap jika diberikan pengalaman belanja yang positif.
#   - Churned Customers : Pelanggan yang sudah lama tidak melakukan transaksi. Strategi pemasaran ulang seperti email promosi atau diskon khusus dapat digunakan untuk menarik mereka kembali.
#   - Regular Customers : Pelanggan dengan pola belanja stabil namun tidak menonjol dalam aspek recency, frequency, maupun monetary.
#
# - Dari hasil ini, dapat disimpulkan bahwa strategi pemasaran berbasis segmentasi pelanggan dapat meningkatkan retensi pelanggan dan nilai transaksi secara keseluruhan.
#
# 2. Distribusi Geografis Pelanggan Berdasarkan Kota dan Negara Bagian
# - Analisis geospasial terhadap distribusi pelanggan berdasarkan kota dan negara bagian menunjukkan pola berikut:
#   - Sebagian besar pelanggan berasal dari kota-kota besar, yang mengindikasikan bahwa layanan e-commerce lebih banyak digunakan di wilayah urban dengan infrastruktur yang lebih mendukung.
#   - Negara bagian dengan jumlah pelanggan tertinggi merupakan area dengan potensi pasar terbesar. Strategi pemasaran dan distribusi produk dapat lebih difokuskan di wilayah ini untuk meningkatkan efisiensi bisnis.
#   - daerah dengan jumlah pelanggan lebih sedikit mungkin menghadapi kendala dalam akses ke layanan e-commerce, seperti keterbatasan pengiriman atau kurangnya kesadaran akan layanan yang tersedia. Wilayah ini dapat dijadikan target ekspansi dengan strategi seperti promosi ongkir gratis, diskon wilayah tertentu, atau kampanye pemasaran berbasis lokal.
#   - Pemetaan geospasial juga menunjukkan bahwa beberapa wilayah memiliki nilai transaksi per pelanggan yang lebih tinggi dibandingkan daerah lain. Ini dapat digunakan untuk menentukan strategi harga, produk yang lebih diminati, serta optimasi rantai pasokan.
#
# - Dengan memahami pola geografis ini, bisnis dapat menyesuaikan strategi pemasaran dan logistik untuk meningkatkan kepuasan pelanggan serta memperluas jangkauan pasar di wilayah yang masih memiliki potensi pertumbuhan.
